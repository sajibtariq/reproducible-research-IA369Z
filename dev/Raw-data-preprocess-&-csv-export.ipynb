# %%
import os

mode=['3g','4g','5g'] 

host=[1]  # number of host
algo=['conventional'] # adaptation algorithm 'conv'
net3= ['metro','bus', 'train', 'ferry','car'] # mobility for 3g
net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g
net5=['A_A_Static','D_Driving', 'D_Static'] #'mobility for 5g

doc3=['Am'] # number of operator (1)
doc4=['Am','Bm']   # number of operator (2)
doc5=['Bm']   # number of operator (1)

num = [1,2,3] 
count = 1

for curr in range(count):
    for md in mode:
        if md == '5g':
            for i in net5:
                for j in doc5:
                    for k in num:
                        for ii in host:
                            for m in algo:
                                for l in range(ii):
                                    l=l+1
                                    os.system('tcpdump -r  ~/reproducible-research-IA369Z/testbed/experiment/experiment/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'_ap.pcap -w  /media/loop/Backup/experiment/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'/new-pcap-file-host-10.0.0.'+ str(l)+ '.pcap  host 10.0.0.'+ str(l))
                              
        elif md =='4g':
            for i in net4:
                for j in doc4:
                    for k in num:
                        for ii in host:
                            for m in algo:
                                 for l in range(ii):
                                    l=l+1
                                    print(l)
                                    os.system('tcpdump -r  ~/reproducible-research-IA369Z/testbed/experiment/experiment/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'_ap.pcap -w  /media/loop/Backup/experiment/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'/new-pcap-file-host-10.0.0.'+ str(l)+ '.pcap  host 10.0.0.'+ str(l))
        elif md =='3g':
            for i in net3:
                for j in doc3:
                    for k in num:
                        for ii in host:
                            for m in algo:
                                 for l in range(ii):
                                        l=l+1
                                        os.system('tcpdump -r  ~/reproducible-research-IA369Z/testbed/experiment/experiment/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'_ap.pcap -w  /media/loop/Backup/experiment/mode_'+str(md)+'_net_'+str(i)+'_doc_'+str(j)+'_num_'+str(k)+'_host_'+str(ii)+'_algo_'+str(m)+'/new-pcap-file-host-10.0.0.'+ str(l)+ '.pcap  host 10.0.0.'+ str(l))

# %%
import nest_asyncio
nest_asyncio.apply()
import pandas as pd
from scapy.all import *

mode=['3g','4g','5g'] 

host=[1]  # number of host
algo=['conventional'] # adaptation algorithm 'conv'
net3= ['metro','bus', 'train', 'ferry','car'] # mobility for 3g
net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g
net5=['A_A_Static','D_Driving', 'D_Static'] #'mobility for 5g

doc3=['Am'] # number of operator (1)
doc4=['Am','Bm']   # number of operator (2)
doc5=['Bm']   # number of operator (1)

num = [1,2,3] 
count = 1

net=[]
doc=[]
nu=[]

for curr in range(count):
    for md in mode:
        if md == '3g': net=net3 :doc=doc3:nu=num
        elif md == '4g':net=net4:doc=doc4:nu=num
        elif md == '5g':net=net5:doc=doc5:nu=num
       
        for ii in net:
            for jj in doc:
                for kk in nu:
                    for ll in host:
                        for mm in algo:
                            for ss in range(ll):
                                ss=ss+1
                                
                
                                os.system('echo mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'.txt')
                                try:
                                    data=pd.read_csv('~/reproducible-research-IA369Z/testbed/experiment/experiment/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_client_sta'+str(ss)+'_host_'+str(ll)+'_algo_'+str(mm)+'.txt', delim_whitespace=True, header=None)
                                    print('dash logfile')
                                    data=data.drop([0])
                                    pcap =rdpcap('~/reproducible-research-IA369Z/testbed/experiment/experiment/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'/new-pcap-file-host-10.0.0.'+ str(ss)+'.pcap')
                                    print('read cap')
        
                                    reset= []

                                    for p in pcap:
                                        if p.haslayer(TCP) and (p[TCP].flags == 'RA' or p[TCP].flags == 'R') : #reset,ack or reset flag
                                            if p[IP].src == '10.0.0.150': #server port
                                                #print("2015-----")
                                                #print(p[TCP].sport)
                                                #print(p[TCP].dport)
                                                reset.append(p[TCP].dport)
                                            else:
                                                #print("not 2015---")
                                                reset.append(p[TCP].sport)
                                                #print(p[TCP].sport)
                                                #print(p[TCP].dport)
                
                                    print(sorted(reset))
                                    print(len(reset))
                                
            
        
                                    connection=[]; connection_sip=[]; connection_dip=[]; connection_sport=[]; connection_sip=[]
                                    c=0
                                    pcap[1].show(
                                    extra=0; segg=1; array=[]; array2=[]
                                    for ppp in pcap:
                                   
                                        if (ppp.haslayer(TCP)) and ( ppp[TCP].sport not in reset):
                                            print('fuu'+str(ppp[TCP].sport))
                                            if Raw in ppp[TCP]:
                                                if(ppp[IP].dst == '10.0.0.150'):# server ip
                                                    if 'GET' in str(ppp[Raw]):
                                                        connection.append(c)
                                                        c=c+1
                                                        connection_sip.append(ppp[IP].src)
                                                        connection_sport.append(ppp[TCP].sport)
                                                        if ("bbb_enc_x264_dash.mpd" in str(ppp[Raw]) or "bbb_enc_x264_dash_init.mp4"  in str(ppp[Raw])):
                                                                extra=extra+1
                                                    
                                    #print(extra)                  
                                    conn=[] ;ij=extra-1;ik=0            
                                    conn=sorted(list(set(connection_sport)))                    
                                    for q in range(len(conn)-extra):
                                        for qq in pcap:
                                            if  qq.haslayer(TCP) and ((qq[TCP].sport == conn[q+extra])):
                                                if Raw in qq[TCP]:
                                                    if(qq[IP].dst == '10.0.0.150'):# server ip
                                                        if 'GET' in str(qq[Raw]):
                                                            print(str((q+extra)-ij) )
                                                            if ((q+extra)-ij)>59:
                                                                break
                                                            if 'segment'+str((q+extra)-ij) in str(qq[Raw]):
                                                                array.append(qq[TCP].sport)
                                                                print(str((q+extra)-ij) )
                                                                print("conn:"+str(conn[(q+extra)-ij]))
                                                                print(array)
                                                                segg=segg+1
                                                                #ij=3
                                                            #print(segg)
                                                            #perint
                                                            else:
                                                                ik=ik+1
                                                                array2.append((q+extra)-ij)
                                                                ij=extra-(1+ik)
                                                                                                    
                                    print(len(connection))

                                    df= pd.DataFrame(columns=['Type','Mobility','Operator','Trace','Total host','Client','Algorithm','Port','Segment','RTT','Throughput', 'Packets', 'MOS','Stall Duration','Rep_level', 'Byte Size', 'Buffer level', 'Width', 'Height'])# rtt=uplink ms, th=downlink byte per sec, sp= downlink packets

                                    t1=0;t2=0;l=0;inner =True;k=0;b=True;s=0;

                                    i=1; 
                                    length= (len(connection))-extra
                                    print(extra)
                                    print(length)
                                    m=extra
                                        
                                    for j in range(len(conn)-m):
                                   
                                    
                                            pac1= True;pac= True; ttt=True;f=True; c=0;tc= True; r1=0; initrtt=0; r2=0;  inner=True; inner2=False;httprtt=0; aaa=0;summ=0;l=0;tspop=0
                                            for p in pcap:
                                        
                                                if p.haslayer(TCP) and (p[TCP].sport == conn[j+m] or p[TCP].dport== conn[j+m]):
                                            
                                                    if pac:
                                                        p1_t=p.time
                                                        pac=False
                                    
                                        
                                                    if(p[IP].dst == connection_sip[1]):  
                                                           if(  p[TCP].flags == 'SA'):
                                                              if(tc==True):
                                                                p2_t= p.time
                                                                initrtt= (p2_t - p1_t) * 1000
                                                                print("initrtt" + str(initrtt))
                                                                tc=False
                        
                                                    
                                                    if  p[IP].src == connection_sip[j+m] and pac1 and  Raw in p[TCP]:
                                            
                                                        r1 = p.time
                                                        print('r1---'+ str(r1))
                                                        pac1 = False
                                                        print(p[IP].src) 
                                                
                    
                                                    if p[IP].dst == connection_sip[j+m]:
                                                  
                                                         if Raw in p[TCP]:
                                                            l=l+int(len(p[Raw]))
                                                            if len(p[TCP]) > 32:
                                                                    pcakets=p[TCP]
                                                                    tstop=p.time
                                                                    c=c+1
             
                                                         if ttt and (p[TCP].flags == 'A' or p[TCP].flags == 'PA'): #ack
                                                             r2=p.time
                                                             httprtt= r2 - r1
                                                             print('r2---'+ str(r2))
                                                             aaa= httprtt * 1000
                                                             summ= (initrtt+aaa)/2
                                                             ttt=False
                                            
                                                
                                                    if p[TCP].flags == 'FA':# fin
                                                
                                                        th=float(l/(tstop-r1))# throughput
                                                        if j+m in array2:
                                                            i=i+1
                                                            continue
                                                        df.loc[i]=[md ,ii, jj, kk, ll, ll, mm, conn[j+m], i ,aaa ,th ,c , data.iloc[i-1,15], data.iloc[i-1,3], data.iloc[i-1,4], data.iloc[i-1,7], data.iloc[i-1,8], data.iloc[i-1,11], data.iloc[i-1,12]]
                                                        i=i+1
                                                        print(df)
                                            
                                                        break
                                       #Don't forget              
                        
                                    export_csv = df.to_csv ('~/reproducible-research-IA369Z/testbed/experiment/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_client_sta'+str(ss)+'_host_'+str(ll)+'_algo_'+str(mm)+'_111.csv', index = None, header=True) #Don't forget              
                                    print('done')
                                    df.iloc[0:0]
                                    data.iloc[0:0]
                        
                                except:
                                    os.system('echo mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'.txt')
                                    pass

# %%
import pandas as pd
import logging



mode=['3g','4g','5g'] 

host=[1]  # number of host
algo=['conventional'] # adaptation algorithm 'conv'
net3= ['metro','bus', 'train', 'ferry','car'] # mobility for 3g
net4=['bus', 'train', 'static','car','pedestrian'] # mobility for 4g
net5=['A_A_Static','D_Driving', 'D_Static'] #'mobility for 5g

doc3=['Am'] # number of operator (1)
doc4=['Am','Bm']   # number of operator (2)
doc5=['Bm']   # number of operator (1)

num = [1,2,3] 
count = 1
count = 1

df=pd.DataFrame(columns=['Type','Mobility','Operator','Trace','Total host','Client','Algorithm','Port','Segment','RTT','Throughput', 'Packets', 'MOS','Stall Duration','Rep_level', 'Byte Size', 'Buffer level', 'Width', 'Height'])


for curr in range(count):
        for md in mode:
            if md =='3g':
                for ii in net3:
                    for jj in doc3:
                        for kk in num:
                            for ll in host:
                                for mm in algo:
                                    for ss in range(ll):
                                        ss=ss+1
                                        try:
                                            d= pd.read_csv('~/reproducible-research-IA369Z/testbed/experiment/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+ '_host_'+ str(ll) +'_algo_'+str(mm)+'_111.csv')
                                            #print(ii )
                                            df=df.append(d) 
                                            df.iloc[0:0]
                                          
                                        except:
                                            logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass
            if md =='4g':
                for ii in net4:
                    for jj in doc4:
                        for kk in num:
                            for ll in host:
                                for mm in algo:
                                     for ss in range(ll):
                                        ss=ss+1
                                        try:
                                            d= pd.read_csv('~/reproducible-research-IA369Z/testbed/experiment/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+  '_host_'+ str(ll) +'_algo_'+str(mm)+'_111.csv')
                                            #print(ii )
                                            df=df.append(d) 
                                            df.iloc[0:0]
                                          
                                        except:
                                            logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass
            if md =='5g':
                for ii in net5:
                    for jj in doc5:
                        for kk in num:
                            for ll in host:
                                for mm in algo:
                                     for ss in range(ll):
                                        ss=ss+1
                                        try:
                                            d= pd.read_csv('~/reproducible-research-IA369Z/testbed/experiment/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm)+'/mode_'+str(md)+'_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+ str(ll) +'_algo_'+str(mm)+'_111.csv')
                                            #print(ii )
                                            df=df.append(d) 
                                            df.iloc[0:0]
                                          
                                        except:
                                            logging.error('CSV filemissing: mode_'+str(md)+ '_net_'+str(ii)+'_doc_'+str(jj)+'_num_'+str(kk)+'_host_'+str(ll)+'_algo_'+str(mm))
                                            pass
            
    
export_csv = df.to_csv('~/reproducible-research-IA369Z/data/Final_conventional.csv', index = None, header=True)
